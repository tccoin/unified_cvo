# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
frame_n = 32
traj_ba = np.loadtxt(f'../test_data/{frame_n}frame/traj_out.txt')
traj_cvo = np.loadtxt(f'../test_data/{frame_n}frame/cvo_track_poses.txt')
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# ax.scatter(traj_ba[:,3],traj_ba[:,7],traj_ba[:,11], c=np.arange(len(traj_ba)), cmap=mpl.colormaps['copper'])
ax.scatter(traj_cvo[:,3],traj_cvo[:,7],traj_cvo[:,11], c=np.arange(len(traj_cvo)), cmap=mpl.colormaps['winter'])
# traj_ba[:,[3,7,11]]

# %%
traj_ba = np.loadtxt('../results/cvo_intensity_img_gpu0_oct25_best/05.txt') #traj_out
plt.plot(traj_ba[:,3],traj_ba[:,11])
# traj_ba[:,[3,7,11]]

# %%
traj_ba = np.loadtxt('../test_data/05_gt.txt') #traj_out
plt.plot(traj_ba[:,3],traj_ba[:,11])
# traj_ba[:,[3,7,11]]
